# %% [markdown]
# Input format:
# - documents file  `[doc_id, docurl, title, doc_body]`
# - qrels file `[topic_id, _, docid, rel]`
# - queries file `[topic_id, querystring]`
# - lookup file `[doc_id, _, offset]`
#
# **THE LABELS ARE INVERTED IN ORDER TO COMPLY WITH BERT NEXT SENTENCE PREDICTION**|

# %%
import os
import gzip
import csv
import random
from collections import defaultdict
from tqdm import tqdm_notebook as tqdm

split = 'train'
data_home = "/ssd2/arthur/TREC2019/data/"
queries_file = os.path.join(data_home, f"msmarco-doc{split}-queries.tsv.gz")
lookup_file = os.path.join(data_home, "msmarco-docs-lookup.tsv.gz")
qrels_file = os.path.join(data_home, f"msmarco-doc{split}-qrels.tsv.gz")

top_100_file = os.path.join(data_home, f"msmarco-doc{split}-top100.gz")
docs_file = os.path.join(data_home, "msmarco-docs.tsv")
outfile = os.path.join(data_home, f'{split}-samples.tsv')


querystring = {}
with gzip.open(queries_file, 'rt', encoding='utf-8') as f:
    tsvreader = csv.reader(f, delimiter="\t")
    for [topicid, querystring_of_topicid] in tsvreader:
        querystring[topicid] = querystring_of_topicid
        
docoffset = {}
with gzip.open(lookup_file, 'rt', encoding='utf-8') as f:
    tsvreader = csv.reader(f, delimiter="\t")
    for [docid, _, offset] in tsvreader:
        docoffset[docid] = int(offset)

qrel = {}
with gzip.open(qrels_file, 'rt', encoding='utf8') as f:
    tsvreader = csv.reader(f, delimiter="\t")
    for [topicid, _, docid, rel] in tsvreader:
        assert rel == "1"
        if topicid in qrel:
            qrel[topicid].append(docid)
        else:
            qrel[topicid] = [docid]

# %%
def getcontent(docid, f):
    """getcontent(docid, f) will get content for a given docid (a string) from filehandle f.
    The content has four tab-separated strings: docid, url, title, body.
    """

    f.seek(docoffset[docid])
    line = f.readline()
    assert line.startswith(docid + "\t"), \
        f"Looking for {docid}, found {line}"
    return line.rstrip()

# %%
# !cat $top_100_file | gzip -d | wc -l
# Out:
# 36701116

# %%
#for each positive sample on qrels, generate 10 negative samples.
stats = defaultdict(int)
n_neg_to_keep = 4
n_negatives_for_topic_id=0
lines_written = 0

if split=="dev":
    total_lines = 519300

elif split=="train":
    total_lines = 36701116


unjudged_rank_to_keep = random.choices(range(1,100), k=n_neg_to_keep)
positive_sample_done = set()

    with gzip.open(top_100_file, 'rt', encoding='utf-8') as top100f, open(docs_file, encoding='utf-8') as f, open(outfile, 'w', encoding='utf-8') as outf:
        for line in tqdm(top100f, total=total_lines):
            [topicid, _, unjudged_docid, rank, _, _ ] = line.split()

            #Either we have already processed this topic or this is an unjudged sample we don't want to keep
            if n_negatives_for_topic_id >= n_neg_to_keep or int(rank) not in unjudged_rank_to_keep:
ls
# Out:
# HBox(children=(IntProgress(value=0, max=36701116), HTML(value='')))
# 1000
# 2000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 47000
# 49000
# 50000
# 51000
# 52000
# 53000
# 54000
# 55000
# 56000
# 57000
# 59000
# 60000
# 61000
# 62000
# 64000
# 65000
# 66000
# 67000
# 68000
# 70000
# 71000
# 72000
# 73000
# 75000
# 76000
# 77000
# 78000
# 79000
# 80000
# 81000
# 82000
# 84000
# 85000
# 86000
# 87000
# 90000
# 91000
# 92000
# 96000
# 97000
# 98000
# 99000
# 100000
# 101000
# 102000
# 103000
# 104000
# 105000
# 107000
# 108000
# 109000
# 110000
# 111000
# 112000
# 113000
# 115000
# 116000
# 117000
# 118000
# 119000
# 120000
# 121000
# 122000
# 123000
# 124000
# 126000
# 127000
# 128000
# 129000
# 131000
# 132000
# 133000
# 134000
# 135000
# 137000
# 138000
# 139000
# 140000
# 141000
# 142000
# 143000
# 144000
# 145000
# 146000
# 148000
# 150000
# 151000
# 153000
# 154000
# 155000
# 156000
# 157000
# 158000
# 159000
# 160000
# 161000
# 162000
# 163000
# 164000
# 165000
# 166000
# 168000
# 169000
# 170000
# 171000
# 172000
# 174000
# 175000
# 176000
# 178000
# 181000
# 182000
# 183000
# 184000
# 185000
# 186000
# 189000
# 191000
# 194000
# 195000
# 196000
# 197000
# 198000
# 199000
# 200000
# 201000
# 203000
# 204000
# 205000
# 206000
# 207000
# 208000
# 210000
# 211000
# 212000
# 213000
# 214000
# 216000
# 217000
# 218000
# 219000
# 220000
# 221000
# 222000
# 226000
# 227000
# 228000
# 230000
# 231000
# 232000
# 233000
# 234000
# 235000
# 236000
# 237000
# 238000
# 239000
# 240000
# 241000
# 242000
# 244000
# 245000
# 246000
# 247000
# 248000
# 250000
# 251000
# 254000
# 256000
# 257000
# 258000
# 259000
# 260000
# 262000
# 263000
# 264000
# 265000
# 266000
# 268000
# 269000
# 270000
# 271000
# 272000
# 273000
# 275000
# 278000
# 279000
# 280000
# 282000
# 283000
# 284000
# 285000
# 286000
# 287000
# 288000
# 289000
# 290000
# 291000
# 292000
# 293000
# 294000
# 296000
# 297000
# 298000
# 299000
# 300000
# 301000
# 302000
# 303000
# 304000
# 305000
# 306000
# 307000
# 308000
# 309000
# 310000
# 312000
# 315000
# 316000
# 320000
# 321000
# 322000
# 323000
# 326000
# 327000
# 328000
# 329000
# 330000
# 331000
# 333000
# 334000
# 335000
# 336000
# 337000
# 338000
# 339000
# 340000
# 341000
# 342000
# 343000
# 344000
# 345000
# 346000
# 347000
# 348000
# 349000
# 350000
# 351000
# 352000
# 353000
# 354000
# 355000
# 356000
# 357000
# 358000
# 359000
# 360000
# 362000
# 363000
# 364000
# 366000
# 367000
# 368000
# 369000
# 370000
# 371000
# 373000
# 376000
# 377000
# 378000
# 379000
# 380000
# 381000
# 382000
# 383000
# 384000
# 385000
# 386000
# 389000
# 391000
# 392000
# 393000
# 394000
# 395000
# 396000
# 397000
# 398000
# 399000
# 400000
# 401000
# 402000
# 404000
# 406000
# 407000
# 408000
# 409000
# 410000
# 411000
# 414000
# 415000
# 416000
# 417000
# 418000
# 419000
# 420000
# 421000
# 422000
# 423000
# 424000
# 426000
# 427000
# 428000
# 429000
# 430000
# 432000
# 434000
# 435000
# 436000
# 437000
# 438000
# 439000
# 440000
# 442000
# 443000
# 444000
# 445000
# 446000
# 447000
# 448000
# 449000
# 450000
# 451000
# 453000
# 454000
# 455000
# 456000
# 457000
# 459000
# 460000
# 461000
# 464000
# 465000
# 466000
# 467000
# 468000
# 469000
# 470000
# 471000
# 472000
# 473000
# 474000
# 475000
# 476000
# 477000
# 478000
# 479000
# 480000
# 481000
# 482000
# 483000
# 484000
# 485000
# 486000
# 487000
# 488000
# 489000
# 490000
# 491000
# 492000
# 493000
# 494000
# 495000
# 497000
# 499000
# 500000
# 501000
# 502000
# 503000
# 504000
# 505000
# 506000
# 507000
# 509000
# 510000
# 511000
# 512000
# 513000
# 515000
# 516000
# 517000
# 518000
# 519000
# 520000
# 521000
# 522000
# 523000
# 525000
# 526000
# 528000
# 529000
# 530000
# 531000
# 532000
# 533000
# 534000
# 535000
# 536000
# 537000
# 538000
# 539000
# 540000
# 541000
# 543000
# 544000
# 545000
# 546000
# 547000
# 549000
# 550000
# 551000
# 552000
# 553000
# 554000
# 555000
# 556000
# 558000
# 559000
# 561000
# 562000
# 563000
# 564000
# 565000
# 566000
# 567000
# 568000
# 569000
# 572000
# 573000
# 574000
# 575000
# 576000
# 577000
# 578000
# 579000
# 581000
# 582000
# 583000
# 584000
# 585000
# 586000
# 587000
# 588000
# 589000
# 590000
# 592000
# 593000
# 594000
# 595000
# 597000
# 598000
# 600000
# 601000
# 602000
# 603000
# 605000
# 606000
# 607000
# 609000
# 610000
# 612000
# 613000
# 615000
# 616000
# 617000
# 618000
# 619000
# 621000
# 622000
# 623000
# 624000
# 625000
# 626000
# 627000
# 628000
# 629000
# 630000
# 631000
# 632000
# 634000
# 635000
# 637000
# 639000
# 640000
# 641000
# 642000
# 643000
# 644000
# 645000
# 646000
# 647000
# 648000
# 649000
# 650000
# 651000
# 653000
# 654000
# 655000
# 658000
# 659000
# 661000
# 662000
# 663000
# 665000
# 666000
# 668000
# 669000
# 671000
# 672000
# 673000
# 674000
# 675000
# 677000
# 678000
# 679000
# 681000
# 682000
# 684000
# 685000
# 686000
# 687000
# 688000
# 689000
# 690000
# 694000
# 695000
# 696000
# 697000
# 698000
# 700000
# 701000
# 702000
# 703000
# 704000
# 705000
# 706000
# 707000
# 708000
# 710000
# 711000
# 712000
# 713000
# 714000
# 715000
# 716000
# 717000
# 718000
# 719000
# 721000
# 722000
# 723000
# 724000
# 725000
# 726000
# 727000
# 728000
# 729000
# 730000
# 731000
# 733000
# 734000
# 735000
# 736000
# 738000
# 739000
# 740000
# 741000
# 742000
# 743000
# 744000
# 745000
# 746000
# 747000
# 748000
# 749000
# 751000
# 752000
# 753000
# 754000
# 755000
# 756000
# 757000
# 758000
# 759000
# 760000
# 761000
# 762000
# 763000
# 764000
# 765000
# 766000
# 767000
# 768000
# 769000
# 770000
# 771000
# 773000
# 774000
# 775000
# 777000
# 778000
# 781000
# 782000
# 783000
# 784000
# 785000
# 786000
# 787000
# 788000
# 790000
# 792000
# 793000
# 794000
# 795000
# 797000
# 798000
# 799000
# 801000
# 802000
# 803000
# 804000
# 805000
# 806000
# 807000
# 808000
# 809000
# 811000
# 812000
# 814000
# 815000
# 816000
# 817000
# 818000
# 819000
# 820000
# 821000
# 822000
# 823000
# 824000
# 827000
# 828000
# 829000
# 830000
# 831000
# 832000
# 833000
# 834000
# 835000
# 836000
# 838000
# 840000
# 841000
# 842000
# 843000
# 845000
# 846000
# 847000
# 848000
# 849000
# 850000
# 851000
# 852000
# 853000
# 854000
# 856000
# 857000
# 858000
# 859000
# 860000
# 861000
# 862000
# 863000
# 864000
# 865000
# 869000
# 870000
# 872000
# 873000
# 874000
# 875000
# 878000
# 879000
# 880000
# 881000
# 882000
# 883000
# 884000
# 886000
# 887000
# 889000
# 890000
# 891000
# 892000
# 893000
# 894000
# 895000
# 896000
# 897000
# 898000
# 899000
# 900000
# 901000
# 902000
# 903000
# 905000
# 906000
# 907000
# 909000
# 910000
# 913000
# 914000
# 915000
# 916000
# 917000
# 919000
# 920000
# 921000
# 922000
# 923000
# 925000
# 926000
# 927000
# 928000
# 929000
# 930000
# 932000
# 933000
# 935000
# 936000
# 939000
# 940000
# 941000
# 942000
# 944000
# 945000
# 946000
# 947000
# 948000
# 949000
# 950000
# 951000
# 952000
# 953000
# 954000
# 955000
# 956000
# 957000
# 958000
# 959000
# 961000
# 962000
# 964000
# 965000
# 966000
# 967000
# 968000
# 969000
# 970000
# 974000
# 975000
# 976000
# 977000
# 978000
# 979000
# 980000
# 981000
# 982000
# 983000
# 984000
# 985000
# 986000
# 987000
# 988000
# 989000
# 990000
# 992000
# 993000
# 994000
# 995000
# 996000
# 997000
# 998000
# 999000
# 1000000
# 1001000
# 1005000
# 1007000
# 1008000
# 1010000
# 1011000
# 1012000
# 1013000
# 1014000
# 1015000
# 1016000
# 1017000
# 1018000
# 1019000
# 1022000
# 1023000
# 1024000
# 1027000
# 1028000
# 1029000
# 1030000
# 1031000
# 1032000
# 1033000
# 1034000
# 1035000
# 1036000
# 1037000
# 1038000
# 1039000
# 1040000
# 1041000
# 1042000
# 1043000
# 1044000
# 1045000
# 1046000
# 1047000
# 1048000
# 1049000
# 1050000
# 1051000
# 1052000
# 1053000
# 1054000
# 1055000
# 1057000
# 1058000
# 1059000
# 1060000
# 1061000
# 1064000
# 1065000
# 1066000
# 1067000
# 1070000
# 1072000
# 1074000
# 1075000
# 1076000
# 1077000
# 1078000
# 1080000
# 1081000
# 1082000
# 1083000
# 1084000
# 1086000
# 1087000
# 1088000
# 1089000
# 1090000
# 1091000
# 1092000
# 1094000
# 1095000
# 1096000
# 1097000
# 1098000
# 1099000
# 1100000
# 1101000
# 1102000
# 1103000
# 1104000
# 1105000
# 1106000
# 1107000
# 1108000
# 1109000
# 1110000
# 1111000
# 1112000
# 1113000
# 1114000
# 1116000
# 1118000
# 1119000
# 1120000
# 1121000
# 1122000
# 1124000
# 1125000
# 1126000
# 1127000
# 1128000
# 1129000
# 1130000
# 1131000
# 1132000
# 1138000
# 1139000
# 1141000
# 1143000
# 1144000
# 1145000
# 1146000
# 1148000
# 1151000
# 1152000
# 1153000
# 1154000
# 1155000
# 1156000
# 1157000
# 1159000
# 1160000
# 1161000
# 1163000
# 1164000
# 1165000
# 1166000
# 1167000
# 1168000
# 1169000
# 1172000
# 1173000
# 1174000
# 1175000
# 1176000
# 1178000
# 1179000
# 1180000
# 1181000
# 1182000
# 1183000
# 1184000
# 1185000
# 1186000
# 1187000
# 1188000
# 1189000
# 1190000
# 1191000
# 1192000
# 1193000
# 1194000
# 1195000
# 1196000
# 1198000
# 1199000
# 1200000
# 1201000
# 1202000
# 1203000
# 1204000
# 1205000
# 1206000
# 1207000
# 1210000
# 1211000
# 1212000
# 1213000
# 1214000
# 1215000
# 1216000
# 1217000
# 1218000
# 1219000
# 1221000
# 1223000
# 1224000
# 1225000
# 1226000
# 1228000
# 1229000
# 1230000
# 1231000
# 1233000
# 1235000
# 1237000
# 1238000
# 1239000
# 1242000
# 1244000
# 1245000
# 1246000
# 1247000
# 1248000
# 1250000
# 1251000
# 1253000
# 1254000
# 1255000
# 1257000
# 1259000
# 1260000
# 1261000
# 1262000
# 1263000
# 1265000
# 1266000
# 1267000
# 1268000
# 1269000
# 1271000
# 1272000
# 1273000
# 1274000
# 1275000
# 1276000
# 1277000
# 1278000
# 1279000
# 1280000
# 1281000
# 1282000
# 1283000
# 1284000
# 1285000
# 1286000
# 1287000
# 1290000
# 1291000
# 1292000
# 1293000
# 1294000
# 1295000
# 1296000
# 1297000
# 1298000
# 1299000
# 1300000
# 1302000
# 1305000
# 1306000
# 1307000
# 1308000
# 1309000
# 1311000
# 1312000
# 1315000
# 1317000
# 1318000
# 1320000
# 1321000
# 1322000
# 1323000
# 1324000
# 1325000
# 1326000
# 1327000
# 1328000
# 1329000
# 1330000
# 1331000
# 1333000
# 1334000
# 1335000
# 1336000
# 1338000
# 1339000
# 1340000
# 1342000
# 1343000
# 1344000
# 1345000
# 1346000
# 1349000
# 1350000
# 1351000
# 1352000
# 1353000
# 1354000
# 1355000
# 1356000
# 1357000
# 1358000
# 1359000
# 1360000
# 1361000
# 1362000
# 1363000
# 1364000
# 1365000
# 1366000
# 1367000
# 1368000
# 1369000
# 1370000
# 1371000
# 1372000
# 1373000
# 1374000
# 1375000
# 1376000
# 1377000
# 1379000
# 1380000
# 1381000
# 1382000
# 1383000
# 1384000
# 1385000
# 1386000
# 1387000
# 1388000
# 1389000
# 1390000
# 1392000
# 1393000
# 1394000
# 1395000
# 1396000
# 1397000
# 1399000
# 1400000
# 1402000
# 1403000
# 1404000
# 1405000
# 1406000
# 1407000
# 1409000
# 1410000
# 1411000
# 1413000
# 1414000
# 1415000
# 1416000
# 1419000
# 1420000
# 1422000
# 1423000
# 1425000
# 1426000
# 1427000
# 1428000
# 1429000
# 1430000
# 1432000
# 1433000
# 1434000
# 1435000
# 1436000
# 1437000
# 1438000
# 1439000
# 1440000
# 1441000
# 1442000
# 1443000
# 1444000
# 1445000
# 1446000
# 1447000
# 1448000
# 1449000
# 1450000
# 1452000
# 1453000
# 1454000
# 1455000
# 1456000
# 1458000
# 1459000
# 1460000
# 1461000
# 1462000
# 1463000
# 1464000
# 1465000
# 1466000
# 1467000
# 1468000
# 1469000
# 1470000
# 1471000
# 1472000
# 1473000
# 1474000
# 1475000
# 1476000
# 1477000
# 1478000
# 1479000
# 1481000
# 1482000
# 1483000
# 1484000
# 1485000
# 1486000
# 1487000
# 1488000
# 1489000
# 1490000
# 1492000
# 1494000
# 1496000
# 1497000
# 1498000
# 1499000
# 1500000
# 1501000
# 1503000
# 1504000
# 1505000
# 1507000
# 1508000
# 1509000
# 1510000
# 1511000
# 1512000
# 1513000
# 1514000
# 1515000
# 1516000
# 1517000
# 1518000
# 1520000
# 1521000
# 1522000
# 1523000
# 1525000
# 1526000
# 1527000
# 1529000
# 1530000
# 1531000
# 1532000
# 1533000
# 1534000
# 1536000
# 1537000
# 1539000
# 1541000
# 1542000
# 1543000
# 1546000
# 1547000
# 1548000
# 1549000
# 1550000
# 1552000
# 1553000
# 1555000
# 1557000
# 1559000
# 1560000
# 1561000
# 1562000
# 1563000
# 1564000
# 1565000
# 1566000
# 1567000
# 1568000
# 1569000
# 1570000
# 1571000
# 1572000
# 1573000
# 1574000
# 1575000
# 1576000
# 1578000
# 1579000
# 1580000
# 1581000
# 1582000
# 1583000
# 1587000
# 1588000
# 1589000
# 1592000
# 1594000
# 1595000
# 1596000
# 1597000
# 1601000
# 1603000
# 1604000
# 1605000
# 1606000
# 1607000
# 1608000
# 1609000
# 1610000
# 1611000
# 1613000
# 1614000
# 1616000
# 1617000
# 1619000
# 1621000
# 1622000
# 1623000
# 1624000
# 1625000
# 1626000
# 1627000
# 1628000
# 1629000
# 1632000
# 1633000
# 1634000
# 1635000
# 1636000
# 1637000
# 1638000
# 1639000
# 1640000
# 1641000
# 1642000
# 1643000
# 1645000
# 1647000
# 1649000
# 1650000
# 1651000
# 1652000
# 1653000
# 1654000
# 1655000
# 1656000
# 1657000
# 1658000
# 1659000
# 1660000
# 1661000
# 1662000
# 1663000
# 1665000
# 1666000
# 1668000
# 1669000
# 1670000
# 1672000
# 1673000
# 1675000
# 1676000
# 1677000
# 1680000
# 1681000
# 1682000
# 1683000
# 1684000
# 1686000
# 1687000
# 1688000
# 1689000
# 1690000
# 1691000
# 1694000
# 1696000
# 1698000
# 1699000
# 1700000
# 1701000
# 1704000
# 1705000
# 1706000
# 1707000
# 1709000
# 1710000
# 1711000
# 1713000
# 1714000
# 1716000
# 1717000
# 1718000
# 1719000
# 1720000
# 1721000
# 1722000
# 1723000
# 1724000
# 1726000
# 1727000
# 1728000
# 1729000
# 1732000
# 1733000
# 1734000
# 1735000
# 1736000
# 1737000
# 1738000
# 1739000
# 1740000
# 1741000
# 1742000
# 1743000
# 1744000
# 1745000
# 1747000
# 1748000
# 1749000
# 1751000
# 1752000
# 1754000
# 1755000
# 1756000
# 1757000
# 1758000
# 1759000
# 1760000
# 1761000
# 1762000
# 1763000
# 1766000
# 1767000
# 1768000
# 1770000
# 1771000
# 1772000
# 1773000
# 1776000
# 1777000
# 1778000
# 1780000
# 1781000
# 1783000
# 1784000
# 1785000
# 1787000
# 1789000
# 1790000
# 1791000
# 1792000
# 1794000
# 1795000
# 1796000
# 1797000
# 1798000
# 1799000
# 1800000
# 1801000
# 1802000
# 1803000
# 1804000
# 1805000
# 1807000
# 1808000
# 1809000
# 1810000
# 1811000
# 1812000
# 1813000
# 1814000
# 1815000
# 1816000
# 1817000
# 1818000
# 1819000
# 1820000
# 1821000
# 1822000
# 1823000
# 1825000
# 1826000
# 1828000
# 1830000
# 1832000
# 1833000
# 1834000
# 1835000
# 1836000
# 1837000
# 1838000
# 1839000
# 1840000
# 1841000
# 1842000
# 1843000
# 1844000
# 1846000
# 1847000
# 1848000
# 1849000
# 1850000
# 1851000
# 1852000
# 1853000
# 1854000
# 1855000
# 1856000
# 1857000
# 1858000
# 1860000
# 1861000
# 1864000
# 1865000
# 1866000
# 1868000
# 1870000
# 1871000
# 1872000
# 1873000
# 1874000
# 1875000
# 1876000
# 1877000
# 1878000
# 1879000
# 1881000
# 1883000
# 1885000
# 1886000
# 1888000
# 1889000
# 1890000
# 1891000
# 1892000
# 1893000
# 1894000
# 1896000
# 1897000
# 1898000
# 1899000
# 1900000
# 1904000
# 1905000
# 1906000
# 1907000
# 1908000
# 1909000
# 1910000
# 1911000
# 1912000
# 1913000
# 1914000
# 1915000
# 1917000
# 1918000
# 1919000
# 1920000
# 1921000
# 1922000
# 1924000
# 1925000
# 1928000
# 1929000
# 1930000
# 1931000
# 1932000
# 1933000
# 1934000
# 1935000
# 1937000
# 1938000
# 1939000
# 1940000
# 1941000
# 1942000
# 1943000
# 1944000
# 1945000
# 1946000
# 1947000
# 1950000
# 1952000
# 1953000
# 1954000
# 1955000
# 1957000
# 1958000
# 1959000
# 1960000
# 1961000
# 1962000
# 1964000
# 1966000
# 1967000
# 1969000
# 1970000
# 1973000
# 1975000
# 1976000
# 1977000
# 1978000
# 1979000
# 1980000
# 1982000
# 1983000
# 1985000
# 1986000
# 1988000
# 1989000
# 1990000
# 1992000
# 1994000
# 1995000
# 1996000
# 1997000
# 1998000
# 1999000
# 2000000
# 2001000
# 2003000
# 2004000
# 2005000
# 2006000
# 2009000
# 2010000
# 2011000
# 2012000
# 2014000
# 2015000
# 2018000
# 2019000
# 2020000
# 2021000
# 2022000
# 2023000
# 2024000
# 2025000
# 2026000
# 2027000
# 2028000
# 2029000
# 2030000
# 2032000
# 2033000
# 2034000
# 2035000
# 2037000
# 2038000
# 2039000
# 2040000
# 2041000
# 2042000
# 2043000
# 2044000
# 2046000
# 2047000
# 2048000
# 2049000
# 2050000
# 2051000
# 2052000
# 2053000
# 2054000
# 2057000
# 2058000
# 2060000
# 2062000
# 2063000
# 2064000
# 2065000
# 2066000
# 2067000
# 2068000
# 2069000
# 2070000
# 2071000
# 2072000
# 2073000
# 2075000
# 2076000
# 2077000
# 2078000
# 2079000
# 2080000
# 2081000
# 2082000
# 2083000
# 2084000
# 2085000
# 2086000
# 2087000
# 2088000
# 2089000
# 2090000
# 2091000
# 2093000
# 2094000
# 2095000
# 2096000
# 2097000
# 2098000
# 2099000
# 2100000
# 2102000
# 2103000
# 2104000
# 2105000
# 2106000
# 2107000
# 2108000
# 2110000
# 2111000
# 2113000
# 2115000
# 2116000
# 2118000
# 2121000
# 2122000
